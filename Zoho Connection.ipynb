# %% [markdown]
# Get the access token for the self client

# %%
import requests

# Replace with your values
CLIENT_ID = "1000.I4A6G2ILALCPFPEK9CL2TJ3459ON2W"
CLIENT_SECRET = "0be89c96a00191f515ffbed5e9c1d9591c5e82e07d"

GRANT_TOKEN = "1000.792dd58748bc79060c852f9df2393787.6624a8a32a3b4ac1257ee1d91cc2f839"

url = "https://accounts.zoho.in/oauth/v2/token"

payload = {
    "grant_type": "authorization_code",
    "client_id": CLIENT_ID,
    "client_secret": CLIENT_SECRET,
    "code": GRANT_TOKEN
}

response = requests.post(url, params=payload)

print(response.status_code)
print(response.text)

# %% [markdown]
# Using the access token that we have send that as a payload and reveive a text of all the fields data

# %%
import requests

ACCESS_TOKEN = "1000.0fa16a170ae0c848fddd3e125fb4e94d.3db11bc6e4d8240f2c37d948fead8ef9"

API_DOMAIN = "https://www.zohoapis.in"

url = f"{API_DOMAIN}/crm/v7/Contacts"

headers = {
    "Authorization": f"Zoho-oauthtoken {ACCESS_TOKEN}"
}

params = {
    "fields": "Record Id,id,Learner Name,Last_Name,Email,Phone,Created By,Created Time"
}

response = requests.get(url, headers=headers, params=params)

print(response.status_code)
print(response.text)

# %% [markdown]
# Record Id
# Learner Owner.id
# Learner Owner
# Last Name
# Learner Name
# Email
# Phone
# Created By.id
# Created By
# Created Time
# Currency
# Exchange Rate
# Last Activity Time
# Tag
# Description
# Unsubscribed Mode
# Unsubscribed Time
# Change Log Time
# Course Details
# Fee - Paid
# Total - Fees
# Registered Date
# Due - Date -|TechStack|Payment Status-|Paid Due Amount-|Locked|Last Enriched Time|Enrich Status|Paid Due's Date-|Due Remarks|DL Learner ID|Source|Lead crated time|Slack|Visited Stage|Walkin Date-|Batch ID Comments|Location|Course-Comments|Deactivated Date-|Demo Attended Date|Due-Amount-|Visited Date|GST Number|CourseSelect|Invoice Type|Tech-Stack|LMS-|Total - Fees|Fee - Paid|Due-Amount|Due - Date|Walkin Date|Payment Status|Edify Course Select|Drive Folder ID|Drive URL|OldDrive Folder ID|Complementary Course
