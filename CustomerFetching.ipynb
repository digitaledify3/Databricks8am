# %%
customerdf = spark.read.csv("/Workspace/Users/saikiranyadlapalli@gmail.com/customer.txt",inferSchema=True,header=True)

# %%
display(customerdf)

# %%
customerdf.write.mode("overwrite").saveAsTable("training8am.customer")

# %%
# %sql
CREATE VIEW IF NOT EXISTS training8am.customerview AS
select * from training8am.customer

# %%
# %sql
select * from training8am.customerview
